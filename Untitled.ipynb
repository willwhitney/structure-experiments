# %%
import bokeh
from bokeh.plotting import figure, show, output_notebook
from bokeh.charts import Scatter, Line, color
from bokeh import palettes
output_notebook()

import numpy as np
import pandas as pd
import os
import math
import time
from IPython.display import clear_output

colors = palettes.Paired12
basedirs = ['/Volumes/speedy/code/structure-experiments/results',
            '/Volumes/wwhitney/structure-experiments/results']

tooltips = [
    ('Experiment', '@experiment'),
    ('Step', '@step'),
    ('Loss', '@loss'),
    ('Prior divergence', '@priordivergence'),
    ('Transition divergence', '@transdivergence'),
]
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="453fa075-b2ff-4521-8221-e397dd04c3d3">Loading BokehJS ...</span>
#     </div>

# %%
def movingaverage(steps, values, window_size):
    window = np.ones(int(window_size))/float(window_size)

    smooth_values = np.convolve(values, window, 'valid')
    padding = int((len(steps) - len(smooth_values)) / 2)
    aligned_steps = steps[padding : len(steps) - padding]
    return aligned_steps, smooth_values

def sparsify(steps, values, amount):
    if amount < 2: return steps, values
    sparse_steps = []
    sparse_values = []

    for i in range(min(len(steps), len(values))):
        if i % amount == 0:
            sparse_values.append(values[i])
            sparse_steps.append(steps[i])
    return np.array(sparse_steps), np.array(sparse_values)

# %%
def load_result_df(experiment):
    for basedir in basedirs:
        df = pd.DataFrame()
        try:
            path = os.path.join(basedir, experiment, 'results.csv')
            df = pd.read_csv(path, error_bad_lines=False)
            if len(df) > 0:
                break
        except Exception as e:
            print("Error in parsing result:", e)
            continue

    numeric_columns = list(df.columns)
#     numeric_columns.remove('experiment')
    df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors="coerce")
    
    for col in df:
        df["".join(col.split()).lower()] = df[col]
#         df[col.strip().lower()] = df[col]
    df['experiment'] = pd.Series([experiment] * len(df), index=df.index)
    return df

def make_dataframe(results):
    data = pd.DataFrame()
    for experiment in results:
        single_df = load_result_df(experiment)
#         print(single_df)
        data = data.append(single_df, ignore_index=True)
#         print(data)
    return data

# %%
networks = [
    "breakout_skip5_z4_3e4_2",
    "breakout_skip5_z4_3e4_4",
    "breakout_skip5_z4_3e4_3",
    "breakout_skip5_z4_3e4_1",
]

data = make_dataframe(networks)
for facet in ['loss', 'trans divergence']:
    plot = Line(data, x='step', y=facet, 
                color=color(columns='experiment', palette=palettes.Spectral11),
                tools='pan,wheel_zoom,box_zoom,save,reset', 
                active_scroll="wheel_zoom",
                tooltips=tooltips,
                plot_width=900,
                plot_height=600)
    show(plot)

# %%
networks = [
    "urban_z4_3e5_1",
    "urban_z4_1e4_1",
    "urban_z4_3e4_1",
    "urban_z4_1e3_1",
]

data = make_dataframe(networks)
spaced_palette = palettes.linear_palette(palettes.Spectral11, len(networks))
for facet in ['loss', 'trans divergence']:
    plot = Line(data, x='step', y=facet, title="urban",
                color=color(columns='experiment', palette=spaced_palette),
                tools='pan,wheel_zoom,box_zoom,save,reset', 
                active_scroll="wheel_zoom",
                tooltips=tooltips,
                plot_width=900,
                plot_height=600)
    show(plot)

# %%
networks = [
#     "urban_128_z8_3e5_1",
#     "urban_128_z8_1e4_1",
#     "urban_128_z8_3e4_1",
#     "urban_128_z8_1e3_1",
#     "urban_128_dcgan_z8_3e5_1",
#     "urban_128_dcgan_z8_1e4_1",
#     "urban_128_dcgan_z8_3e5_1_restart",
#     "urban_128_dcgan_z8_1e4_1_restart",
#     "urban_128_dcgan_z8_3e4_1_restart",
#     "urban_128_dcgan_z8_1e3_1",
    
#     "urban_128_dcgan_z8_3e4_1",
#     "urban_128_dcgan_z8_1e4_2",
#     "urban_128_dcgan_z8_3e4_2",
#     "urban_128_dcgan_z4_3e4_1",
#     "urban_128_dcgan_z8_shallowtrans_3e4",

#     "urban_2fps_128_dcgan_z8_var0.02_3e4_1",
#     "urban_2fps_128_dcgan_z8_3e4_1",
    
    "urban_2fps_128_dcgan_z8_3e4_2",
    "urban_2fps_128_dcgan_z8_var0.05_3e4_1",
    "urban_2fps_128_dcgan_z8_var0.1_3e4_1",
#     "urban_2fps_128_dcgan_z8_var0.05_gradscale_3e4_1",
    
    "urban_2fps_128_dcgan_z8_var0.05_3e4_2",
    "urban_2fps_128_dcgan_z8_var0.1_3e4_2",
    "urban_2fps_128_dcgan_z1_var0.05_3e4_1",
    "urban_2fps_128_dcgan_z20_h10_var0.05_3e4_1",
]

palette = palettes.Spectral11[:5] + palettes.Spectral11[6:]
data = make_dataframe(networks)
spaced_palette = palettes.linear_palette(palette, len(networks))
for facet in ['loss', 'trans divergence']:
    plot = Line(data, x='step', y=facet, title="urban",
                color=color(columns='experiment', palette=spaced_palette),
                tools='pan,wheel_zoom,box_zoom,save,reset', 
                active_scroll="wheel_zoom",
                tooltips=tooltips,
                plot_width=900,
                plot_height=600,
                legend='top_right')
#     if facet == 'loss':
#         plot.y_range = bokeh.models.Range1d(-70000, -60000)
    if facet == 'trans divergence':
        plot.y_range = bokeh.models.Range1d(0, 80)
    show(plot)

# %%
networks = [    
    "urban_2fps_128_dcgan_z20_h10_var0.05_3e4_2_",
    "urban_2fps_128_dcgan_z8_var0.05_3e4_3_",
    "urban_2fps_128_dcgan_z1_var0.05_3e4_2_",
    "urban_2fps_128_dcgan_z8_var0.1_3e4_3_",
]

palette = palettes.Spectral11[:5] + palettes.Spectral11[6:]
data = make_dataframe(networks)
spaced_palette = palettes.linear_palette(palette, len(networks))
for facet in ['loss', 'trans divergence']:
    plot = Line(data, x='step', y=facet, title="urban",
                color=color(columns='experiment', palette=spaced_palette),
                tools='pan,wheel_zoom,box_zoom,save,reset', 
                active_scroll="wheel_zoom",
                tooltips=tooltips,
                plot_width=900,
                plot_height=600,
                legend='top_right')
#     if facet == 'loss':
#         plot.y_range = bokeh.models.Range1d(-70000, -60000)
    if facet == 'trans divergence':
        plot.y_range = bokeh.models.Range1d(0, 80)
    show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fd134ead-f423-449c-a563-6ffbb6c43257"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("fd134ead-f423-449c-a563-6ffbb6c43257").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fd134ead-f423-449c-a563-6ffbb6c43257");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fd134ead-f423-449c-a563-6ffbb6c43257' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1ff90bd9-d838-4653-8299-a2ca97bf6f10":{"roots":{"references":[{"attributes":{"data_source":{"id":"51949a50-df52-4e1e-8245-ab4453a53a40","type":"ColumnDataSource"},"glyph":{"id":"b93118a6-00ab-4a95-abb0-8f5c90a49409","type":"Line"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5910aa32-8244-4c15-bb41-c90ddd58de54","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values","step","loss","priordivergence","transdivergence"],"data":{"chart_index":[{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},{"experiment":"urban_2fps_128_dcgan_z8_var0 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="536b5a28-109a-40a7-9c66-c3ccfac85e2d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("536b5a28-109a-40a7-9c66-c3ccfac85e2d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("536b5a28-109a-40a7-9c66-c3ccfac85e2d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '536b5a28-109a-40a7-9c66-c3ccfac85e2d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"50264520-e3e7-486e-a2d7-80ebc8a97a66":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0099944c-d437-4126-8724-4e28283e3b22","type":"BoxAnnotation"},{"attributes":{"line_color":{"value":"#9e0142"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"4c0536ec-2d28-44d0-bb74-c57b8ac4e356","type":"Line"},{"attributes":{"data_source":{"id":"85f3b55b-fb61-4f34-8607-0f0749b59f9c","type":"ColumnDataSource"},"glyph":{"id":"4c0536ec-2d28-44d0-bb74-c57b8ac4e356","type":"Line"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8a333048-952e-4256-ba7b-90c17caee500","type":"GlyphRenderer"},{"attributes":{},"id":"56cb890a-7d65-43a4-bfb6-8f02c026df89","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"a48176bb-1e77-4066-b2e1-f464e97bd0c4","subtype":"Chart","type":"Plot"}},"id":"eea5798a-6cc1-4eac-bfed-1f84179ce9b2","type":"PanTool"},{"attributes":{"plot":{"id":"a48176bb-1e77-4066-b2e1-f464e97bd0c4","subtype":"Chart","type":"Plot"}},"id":"7f7978e7-9128-458e-90b7-833008d4db83","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"0099944c-d437-4126-8724-4e28283e3b22","type":"BoxAnnotation"},"plot":{"id":"a48176bb-1e77-4066-b2e1-f464e97bd0c4","subtype":"Chart","type":"Plot"}},"id":"195b9510-b9d2-49a7-86bf-9fc3c1361812","type":"BoxZoomTool"},{"attributes":{"axis_label":"trans divergence","formatter":{"id":"650ce5fa-92d5-4fe8-8603-90a2b2799ed6","type":"BasicTickFormatter"},"plot":{"id":"a48176bb-1e77-4066-b2e1-f464e97bd0c4","subtype":"Chart","type":"Plot"},"ticker":{"id":"1e1a5b7a-dcd8-414b-b208-c555dab258fa","type":"BasicTicker"}},"id":"74262e8e-273f-4099-8386-a263f139cba7","type":"LinearAxis"},{"attributes":{"plot":{"id":"a48176bb-1e77-4066-b2e1-f464e97bd0c4","subtype":"Chart","type":"Plot"}},"id":"2b98fb36-3451-48f0-afa5-a6784de587eb","type":"SaveTool"},{"attributes":{"plot":{"id":"a48176bb-1e77-4066-b2e1-f464e97bd0c4","subtype":"Chart","type":"Plot"}},"id":"d1db0450-f0ef-49b5-a899-53ab5324ecca","type":"ResetTool"},{"attributes":{"label":{"value":"urban_2fps_128_dcgan_z8_var0.05_3e4_3_"},"renderers":[{"id":"4a17cbb4-561d-47f1-b8da-e0da1943474d","type":"GlyphRenderer"}]},"id":"0dc48681-1b3b-4c40-bfe9-fe67004fede6","type":"LegendItem"},{"attributes":{},"id":"784d2c35-b8c2-4090-85e6-6192261efdc4","type":"BasicTicker"},{"attributes":{"plot":{"id":"a48176bb-1e77-4066-b2e1-f464e97bd0c4","subtype":"Chart","type":"Plot"},"ticker":{"id":"784d2c35-b8c2-4090-85e6-6192261efdc4","type":"BasicTicker"}},"id":"90d4b28d-09a0-4cfb-b985-7fa40cf6dba6","type":"Grid"},{"attributes":{"label":{"value":"urban_2fps_128_dcgan_z1_var0.05_3e4_2_"},"renderers":[{"id":"37215581-ac39-4902-a0d4-4616a2d94d3b","type":"GlyphRenderer"}]},"id":"a29d6294-86a3-4f50-9217-9443163659f7","type":"LegendItem"},{"attributes":{},"id":"1e1a5b7a-dcd8-414b-b208-c555dab258fa","type":"BasicTicker"},{"attributes":{"axis_label":"step","formatter":{"id":"56cb890a-7d65-43a4-bfb6-8f02c026df89","type":"BasicTickFormatter"},"plot":{"id":"a48176bb-1e77-4066-b2e1-f464e97bd0c4","subtype":"Chart","type":"Plot"},"ticker":{"id":"784d2c35-b8c2-4090-85e6-6192261efdc4","type":"BasicTicker"}},"id":"5657ee94-5b66-4842-9f26-6586fe35df66","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"a48176bb-1e77-4066-b2e1-f464e97bd0c4","subtype":"Chart","type":"Plot"},"ticker":{"id":"1e1a5b7a-dcd8-414b-b208-c555dab258fa","type":"BasicTicker"}},"id":"3265aae5-2caa-4dbc-bba8-2289a35f0963","type":"Grid"},{"attributes":{"callback":null,"plot":{"id":"a48176bb-1e77-4066-b2e1-f464e97bd0c4","subtype":"Chart","type":"Plot"},"tooltips":[["Experiment","@experiment"],["Step","@step"],["Loss","@loss"],["Prior divergence","@priordivergence" ...

# %%
networks = [    
#     "freeway_128_dcgan_z8_var0.1_3e4_1_",
#     "freeway_128_dcgan_z1_var0.05_3e4_1_",
#     "freeway_128_dcgan_z8_var0.05_3e4_1_",
#     "freeway_128_dcgan_z20_h10_var0.05_3e4_1_",
    "breakout_128_dcgan_z8_var0.1_3e4_1",
    "breakout_128_dcgan_z8_var0.05_3e4_1",
    "breakout_128_dcgan_z1_var0.05_3e4_1",
    "breakout_128_dcgan_z20_h10_var0.05_3e4_1",

]

palette = palettes.Spectral11[:5] + palettes.Spectral11[6:]
data = make_dataframe(networks)
spaced_palette = palettes.linear_palette(palette, len(networks))
for facet in ['loss', 'trans divergence']:
    plot = Line(data, x='step', y=facet, title="atari",
                color=color(columns='experiment', palette=spaced_palette),
                tools='pan,wheel_zoom,box_zoom,save,reset', 
                active_scroll="wheel_zoom",
                tooltips=tooltips,
                plot_width=900,
                plot_height=600,
                legend='top_right')
#     if facet == 'loss':
#         plot.y_range = bokeh.models.Range1d(-70000, -60000)
    if facet == 'trans divergence':
        plot.y_range = bokeh.models.Range1d(0, 80)
    show(plot)
# Out:
# Error in parsing result: File b'/Volumes/speedy/code/structure-experiments/results/breakout_128_dcgan_z8_var0.1_3e4_1/results.csv' does not exist
# Error in parsing result: File b'/Volumes/speedy/code/structure-experiments/results/breakout_128_dcgan_z8_var0.05_3e4_1/results.csv' does not exist
# Error in parsing result: File b'/Volumes/speedy/code/structure-experiments/results/breakout_128_dcgan_z1_var0.05_3e4_1/results.csv' does not exist
# Error in parsing result: File b'/Volumes/speedy/code/structure-experiments/results/breakout_128_dcgan_z20_h10_var0.05_3e4_1/results.csv' does not exist
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="27cb6daf-61fa-4dd0-aa88-34b33e83bc7a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("27cb6daf-61fa-4dd0-aa88-34b33e83bc7a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("27cb6daf-61fa-4dd0-aa88-34b33e83bc7a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '27cb6daf-61fa-4dd0-aa88-34b33e83bc7a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f71fc6e9-057e-45d8-9eab-42dae7d52ce0":{"roots":{"references":[{"attributes":{},"id":"da642d65-e8df-4290-affe-b1f156d9eee9","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"69f5a77d-7d73-47b7-80c7-ba12c7a8e3e3","subtype":"Chart","type":"Plot"},"tooltips":[["Experiment","@experiment"],["Step","@step"],["Loss","@loss"],["Prior divergence","@priordivergence"],["Transition divergence","@transdivergence"]]},"id":"3fa1f63d-2b62-44c4-bba1-fac630092eff","type":"HoverTool"},{"attributes":{},"id":"716917c7-12d4-47cb-9db4-4246a959326d","type":"BasicTicker"},{"attributes":{},"id":"ad3cf132-e9d6-4024-8d13-8886d7fbe1da","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"063a2c3e-ef34-4260-a634-ed130fee9455","type":"ColumnDataSource"},"glyph":{"id":"92b6f1fa-e9d9-405c-8e7e-3e2c9093cefa","type":"Line"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a3d1a865-668a-4014-a350-94052d5e52e9","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values","step","loss","priordivergence","transdivergence"],"data":{"chart_index":[{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e4_1"},{"experiment":"breakout_128_dcgan_z8_var0.1_3e ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ff895165-1ef6-4a46-aabb-b47df753d90a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ff895165-1ef6-4a46-aabb-b47df753d90a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"114351a0-97ad-4c5d-bd0f-0ec7012746c3":{"roots":{"references":[{"attributes":{"items":[{"id":"4f85d6f2-52cf-4951-9ccf-8a7edd027a33","type":"LegendItem"},{"id":"7bb8f060-db0e-4162-a9ac-77975f788143","type":"LegendItem"},{"id":"59013474-432b-4f4b-a91c-2a4bcbd432b6","type":"LegendItem"},{"id":"08e69019-451a-413f-a213-25a115a7201e","type":"LegendItem"}],"plot":{"id":"06b2fb21-9c6e-4d95-8bf0-601b602ccac5","subtype":"Chart","type":"Plot"}},"id":"dc15247c-8b71-4bb8-9956-16eb5e75d6e1","type":"Legend"},{"attributes":{},"id":"326061a5-4c73-4bcb-bade-26141dec9936","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values","step","loss","priordivergence","transdivergence"],"data":{"chart_index":[{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"experiment":"urban_bvae5_klend6e6_hvar0.05_3e4_1_"},{"expe ...

# %%
networks = [    
#     "balls6_width16_var0.05_3e4_1",
#     "balls6_width16_var0.1_klend_1e6_3e4_1",
#     "balls6_width16_var0.1_3e4_1",
#     "balls6_width16_var0.01_3e4_1",
#     "balls6_width16_z6_h10_var0.1_3e4_1",
#     "balls6_width16_z6_h10_var0.01_3e4_1",
#     "balls6_width16_z12_h5_var0.1_3e4_1",
#     "balls6_width16_z12_h5_var0.01_3e4_1",
    
#     "balls6_width16_nokl_var0.01_1e4_1",
#     "balls6_width16_nokl_var0.1_1e4_1",
#     "balls6_width16_shallowtrans_var0.01_3e4_1",
#     "balls6_width16_shallowtrans_z12_h5_var0.01_1e4_1",
#     "balls6_width16_shallowtrans_var0.01_1e4_1",
#     "balls6_width16_nokl_var0.1_3e4_1",
#     "balls6_width16_nokl_var0.01_3e4_1",
#     "balls6_width16_shallowtrans_var0.1_3e4_1",
    
    "balls6_width16_z12_h5_var0.01_3e4_1",
    "balls6_width16_var0.1_3e4_1",
    "balls6_width16_z12_h5_var0.01_1e4_1",
    "balls6_width16_var0.01_1e4_1",
    "balls6_width16_var0.01_3e4_1",
    "balls6_width16_nokl_var0.1_3e4_1",
    "balls6_width16_nokl_var0.01_3e4_1",
]

palette = palettes.Spectral11[:5] + palettes.Spectral11[6:]
data = make_dataframe(networks)
spaced_palette = palettes.linear_palette(palette, len(networks))
for facet in ['loss', 'trans divergence']:
    plot = Line(data, x='step', y=facet, title="balls",
                color=color(columns='experiment', palette=spaced_palette),
                tools='pan,wheel_zoom,box_zoom,save,reset', 
                active_scroll="wheel_zoom",
                tooltips=tooltips,
                plot_width=900,
                plot_height=600,
                legend='top_right')
#     if facet == 'loss':
#         plot.y_range = bokeh.models.Range1d(-70000, -60000)
    if facet == 'trans divergence':
        plot.y_range = bokeh.models.Range1d(-5, 40)
    show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b27fd00b-c246-4976-9860-9a74e4416163"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b27fd00b-c246-4976-9860-9a74e4416163").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b27fd00b-c246-4976-9860-9a74e4416163");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b27fd00b-c246-4976-9860-9a74e4416163' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5eb286a3-acf6-4d40-a425-c924b301e7c5":{"roots":{"references":[{"attributes":{},"id":"dcdebe94-fbcb-41b5-b058-daa88468a6a3","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"9442a87b-d2b2-42d8-87a3-0598198999a7","type":"ColumnDataSource"},"glyph":{"id":"69c4edcd-9b28-4006-9960-2eb9ea552b42","type":"Line"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"44a784d8-4545-4118-8c28-dad1703d2fca","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#3288bd"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"715aa0e9-017c-4794-a409-60cff73565dc","type":"Line"},{"attributes":{"callback":null,"column_names":["x_values","y_values","step","loss","priordivergence","transdivergence"],"data":{"chart_index":[{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_width16_nokl_var0.01_3e4_1"},{"experiment":"balls6_wi ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="949cc797-bad9-4181-9c58-d8890ee20c43"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("949cc797-bad9-4181-9c58-d8890ee20c43").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("949cc797-bad9-4181-9c58-d8890ee20c43");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '949cc797-bad9-4181-9c58-d8890ee20c43' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dfd63166-db24-45d5-95e7-b4a1946654ac":{"roots":{"references":[{"attributes":{"line_color":{"value":"#5e4fa2"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"41d86616-deab-4c9b-b4a0-badddb831cbf","type":"Line"},{"attributes":{"label":{"value":"balls6_width16_nokl_var0.1_3e4_1"},"renderers":[{"id":"6a7642c7-ce97-4b7e-bc14-53776bc27c8d","type":"GlyphRenderer"}]},"id":"2f417317-7f6c-4231-a3b2-2dffeaf5fabe","type":"LegendItem"},{"attributes":{"label":{"value":"balls6_width16_nokl_var0.01_3e4_1"},"renderers":[{"id":"83e7c06c-a34a-4761-93fe-8ebf77ad0519","type":"GlyphRenderer"}]},"id":"4ba33c38-fe1b-4f08-89c5-0c90314e830b","type":"LegendItem"},{"attributes":{"axis_label":"step","formatter":{"id":"053c1034-91d4-425f-ba43-829df712ab1d","type":"BasicTickFormatter"},"plot":{"id":"d96c8798-c687-4086-b21f-04f69e3324f0","subtype":"Chart","type":"Plot"},"ticker":{"id":"00b06273-6246-4f3a-ac17-d581a5518c43","type":"BasicTicker"}},"id":"35625ff8-73ef-4464-8d62-5bde06ed5180","type":"LinearAxis"},{"attributes":{"axis_label":"trans divergence","formatter":{"id":"f90fe2b0-c71c-41fb-aec5-6630da850416","type":"BasicTickFormatter"},"plot":{"id":"d96c8798-c687-4086-b21f-04f69e3324f0","subtype":"Chart","type":"Plot"},"ticker":{"id":"83982f8a-f83e-4518-b347-3a67ffbbe4ad","type":"BasicTicker"}},"id":"ce512903-00d2-4401-826c-8678fedd99f8","type":"LinearAxis"},{"attributes":{"data_source":{"id":"475dde62-728b-4f80-8e38-2d82e9520a89","type":"ColumnDataSource"},"glyph":{"id":"7213caaa-737f-4d25-b902-ffa176aced4e","type":"Line"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0c1d2665-6cf5-499e-bbe6-7ea8af6d1b39","type":"GlyphRenderer"},{"attributes":{},"id":"053c1034-91d4-425f-ba43-829df712ab1d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d96c8798-c687-4086-b21f-04f69e3324f0","subtype":"Chart","type":"Plot"},"ticker":{"id":"00b06273-6246-4f3a-ac17-d581a5518c43","type":"BasicTicker"}},"id":"270949c0-cf72-40ae-a900-48fdf7ef238b","type":"Grid"},{"attributes":{"line_color":{"value":"#abdda4"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"7213caaa-737f-4d25-b902-ffa176aced4e","type":"Line"},{"attributes":{},"id":"83982f8a-f83e-4518-b347-3a67ffbbe4ad","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"d96c8798-c687-4086-b21f-04f69e3324f0","subtype":"Chart","type":"Plot"},"ticker":{"id":"83982f8a-f83e-4518-b347-3a67ffbbe4ad","type":"BasicTicker"}},"id":"acd13375-a973-4f0c-a4e7-53c9dd8f0509","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values","step","loss","priordivergence","transdivergence"],"data":{"chart_index":[{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1_3e4_1"},{"experiment":"balls6_width16_nokl_var0.1 ...

# %%
networks = [    
    "urban_2fps_128_dcgan_z8_var0.05_3e4_3_",
    "urban_128_nosgld_nolrdecay_dcgan_z8_var0.05_3e4_1",
    "urban_128_nosgld_dcgan_z8_var0.05_3e4_1",
]

palette = palettes.Spectral11[:5] + palettes.Spectral11[6:]
data = make_dataframe(networks)
spaced_palette = palettes.linear_palette(palette, len(networks))
for facet in ['loss', 'trans divergence']:
    plot = Line(data, x='step', y=facet, title="with and without SGLD and LR decay",
                color=color(columns='experiment', palette=spaced_palette),
                tools='pan,wheel_zoom,box_zoom,save,reset', 
                active_scroll="wheel_zoom",
                tooltips=tooltips,
                plot_width=900,
                plot_height=600,
                legend='top_right')
#     if facet == 'loss':
#         plot.y_range = bokeh.models.Range1d(-70000, -60000)
    if facet == 'trans divergence':
        plot.y_range = bokeh.models.Range1d(0, 80)
    show(plot)
# Out:
# Error in parsing result: File b'/Volumes/speedy/code/structure-experiments/results/urban_128_nosgld_nolrdecay_dcgan_z8_var0.05_3e4_1/results.csv' does not exist
# Error in parsing result: File b'/Volumes/speedy/code/structure-experiments/results/urban_128_nosgld_dcgan_z8_var0.05_3e4_1/results.csv' does not exist
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2f4f491c-cdb3-44fc-a5f6-6eafd534d7e1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2f4f491c-cdb3-44fc-a5f6-6eafd534d7e1").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2f4f491c-cdb3-44fc-a5f6-6eafd534d7e1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2f4f491c-cdb3-44fc-a5f6-6eafd534d7e1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c16e3001-d153-4152-b0ca-518324ad5b68":{"roots":{"references":[{"attributes":{},"id":"5940f878-dc94-4640-bd13-0259c982f9ef","type":"BasicTicker"},{"attributes":{"axis_label":"step","formatter":{"id":"cd5340a1-42ee-4f52-9d8a-d48486e04b7f","type":"BasicTickFormatter"},"plot":{"id":"afa6f573-ef72-4303-bd71-ad5c28719831","subtype":"Chart","type":"Plot"},"ticker":{"id":"5940f878-dc94-4640-bd13-0259c982f9ef","type":"BasicTicker"}},"id":"a26f2968-62fd-4073-9202-9e6e39c1b715","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x_values","y_values","step","loss","priordivergence","transdivergence"],"data":{"chart_index":[{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_nosgld_dcgan_z8_var0.05_3e4_1"},{"experiment":"urban_128_